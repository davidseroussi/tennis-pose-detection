# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import time

# %%
ret
# Out:
# True

# %%
cap = cv2.VideoCapture('federer_cut.mp4')

while(cap.isOpened()):
    ret, frame = cap.read()
    break

cap.release()
cv2.destroyAllWindows()
# Out:
# -------------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-17-aa246a0400ff> in <module>
#       8         ret, frame = cap.read()
#       9         plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
# ---> 10         time.sleep(10)
#      11     c+=1
#      12
#
# KeyboardInterrupt:
